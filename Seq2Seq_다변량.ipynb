# %%
import warnings 
warnings.filterwarnings(action='ignore')

import math
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score

import pandas as pd 
import numpy as np 
from numpy import array

import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
plt.style.use('seaborn-whitegrid')

from pylab import rcParams
# %matplotlib inline
import itertools

# %%
#한글폰트 적용
import matplotlib.font_manager as fm
path = 'C:/Windows/Fonts/gulim.ttc'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

# %% [markdown]
# ### 수출금액 준비

# %%
pd.set_option('display.max_columns', None)
data = pd.read_csv('수출금액50년.csv',encoding='cp949')
data['Date'] = pd.to_datetime(data['Date'])
data = data.set_index('Date')
print(data.shape)
data.head()
# Out:
# (624, 7)
#             한국수출금액_USD  한국수입금액_USD      무역수지  경기종합지수  한국소비자물가지수  다우존스지수  \
# Date
# 1970-01-31    51046000   149889000 -98843000     4.4      4.400  753.12
# 1970-02-28    46889000   125666000 -78777000     4.5      4.488  777.59
# 1970-03-31    65906000   147048000 -81142000     4.5      4.586  785.57
# 1970-04-30    65910000   153829000 -87919000     4.5      4.684  736.07
# 1970-05-31    69923000   153741000 -83818000     4.6      4.637  700.44
#
#             Exp_불규칙요소
# Date
# 1970-01-31   0.996558
# 1970-02-28   0.879962
# 1970-03-31   1.032904
# 1970-04-30   1.036134
# 1970-05-31   1.045358

# %%
data.dtypes
# Out:
# 한국수출금액_USD      int64
# 한국수입금액_USD      int64
# 무역수지            int64
# 경기종합지수        float64
# 한국소비자물가지수     float64
# 다우존스지수        float64
# Exp_불규칙요소     float64
# dtype: object

# %%
plt.figure(figsize=(14,4))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('수출금액')
plt.plot(data['한국수출금액_USD'], 'blue', label='Train data')
plt.legend()

# %% [markdown]
# ### Input/ Output Sequence & 배열 설정
#     - X 배열
#     - Y 배열

# %%
train = data # 데이터 학습

# %%
train.shape
# Out:
# (624, 7)

# %%
train.columns  # 자료 표시
# Out:
# Index(['한국수출금액_USD', '한국수입금액_USD', '무역수지', '경기종합지수', '한국소비자물가지수', '다우존스지수',
#        'Exp_불규칙요소'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scale_cols =  ['한국수출금액_USD', '한국수입금액_USD', '무역수지', '경기종합지수', '한국소비자물가지수','다우존스지수','Exp_불규칙요소']

scaled_train = scaler.fit_transform(train[scale_cols]) # 전체 데이터 
scaled_train = pd.DataFrame(scaled_train, columns=scale_cols)

feature_train = scaled_train#.drop(['한국수출금액_USD'],axis=1) ##### X_train 다변량 시계열 변수 
label_train = scaled_train[['한국수출금액_USD']]               ####  y_train 종속변수

# %%
def split_sequence(sequence, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequence)):
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out
        if out_end_ix > len(sequence):
            break
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix:out_end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
window_size = 5 # Input Sequence (입력 길이) : X1,X2,....XT 
n_step_out = 6   # Output Sequence (출력 길이) : Y1,Y2,....YT

# %% [markdown]
# ### 1. X 배열

# %%
X,y = split_sequence(feature_train, window_size, n_step_out) # feature_train = X 다변량 변수

# %%
X.shape
# Out:
# (614, 5, 7)

# %% [markdown]
# ### 2. Y 배열

# %%
x, Y = split_sequence(label_train, window_size, n_step_out) # label_train = Y 종속변수 예측값

# %%
Y.shape
# Out:
# (614, 6, 1)

# %% [markdown]
# ### 3. 배열 최종 확인

# %%
X.shape,Y.shape
# Out:
# ((614, 5, 7), (614, 6, 1))

# %% [markdown]
# ### 1. LSTM Encoder & Decoder

# %%
import tensorflow 
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import LSTM, Dense,Flatten,Dropout,GRU,Bidirectional,RepeatVector,TimeDistributed

# %%
tf.random.set_seed(0)

# %%
class MCDropout(Dropout): # 몬테카를로 드롭아웃 
    def call(self, inputs):
        return super().call(inputs, training=True)

# %%
model = Sequential() # Encoder & Decoder

## Encoder state
model.add(LSTM(64,activation='tanh',input_shape=(X.shape[1], X.shape[2]),return_sequences=False))
model.add(MCDropout(0.1))
model.add(Dense(1))
model.add(RepeatVector(6)) # 출력 개수만큼 반복 

## Decoder State
model.add(LSTM(500, activation='tanh', return_sequences=True)) # Decoder State 
model.add(MCDropout(0.1))
model.add(TimeDistributed(Dense(16,activation='relu'))) 
model.add(TimeDistributed(Dense(1)))

model.compile(loss='mean_squared_error', optimizer='adam',metrics='mae')
early_stop = EarlyStopping(monitor='val_loss', patience=5)
model.fit(X, Y, epochs= 200, batch_size=20, validation_split=0.1,callbacks=[early_stop])
# Out:
# Epoch 1/200
# 28/28 [==============================] - 7s 147ms/step - loss: 0.0596 - mae: 0.1564 - val_loss: 0.0443 - val_mae: 0.1616
# Epoch 2/200
# 28/28 [==============================] - 1s 33ms/step - loss: 0.0075 - mae: 0.0526 - val_loss: 0.0157 - val_mae: 0.0999
# Epoch 3/200
# 28/28 [==============================] - 1s 27ms/step - loss: 0.0033 - mae: 0.0375 - val_loss: 0.0091 - val_mae: 0.0755
# Epoch 4/200
# 28/28 [==============================] - 1s 27ms/step - loss: 0.0023 - mae: 0.0294 - val_loss: 0.0087 - val_mae: 0.0739
# Epoch 5/200
# 28/28 [==============================] - 1s 31ms/step - loss: 0.0021 - mae: 0.0287 - val_loss: 0.0097 - val_mae: 0.0788
# Epoch 6/200
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0016 - mae: 0.0243 - val_loss: 0.0074 - val_mae: 0.0663
# Epoch 7/200
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0017 - mae: 0.0248 - val_loss: 0.0081 - val_mae: 0.0725
# Epoch 8/200
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0016 - mae: 0.0231 - val_loss: 0.0109 - val_mae: 0.0810
# Epoch 9/200
# 28/28 [==============================] - 1s 36ms/step - loss: 0.0016 - mae: 0.0242 - val_loss: 0.0121 - val_mae: 0.0876
# Epoch 10/200
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0019 - mae: 0.0262 - val_loss: 0.0079 - val_mae: 0.0702
# Epoch 11/200
# 28/28 [==============================] - 1s 34ms/step - loss: 0.0018 - mae: 0.0270 - val_loss: 0.0116 - val_mae: 0.0851

# %%
rcParams['figure.figsize'] = 12, 4

# %%
label_train.plot()
# Out:
# <AxesSubplot:>

# %%
pd.DataFrame(model.predict(X).reshape(-1,1)).plot()
# Out:
# <AxesSubplot:>

# %%
X_test = np.array(feature_train.tail(5)).reshape((1, 5, 7)) # 원 데이터 마지막 입력 변수 시퀀스 --> 향후 예측

# %%
X_test.shape
# Out:
# (1, 5, 7)

# %%
#fit = model.predict(X_test).reshape(-1,1)
#fit

#fit_repeat = np.repeat(fit,6, axis=-1)

#model_fit = scaler.inverse_transform(fit_repeat)
#model_fit = np.squeeze(model_fit)[:,0]
#model_fit

#pd.DataFrame(model_fit).plot()

# %%
model_MC=  model
prediction = [model_MC.predict(X_test) for sample in range(30)]

# %%
dfs = [] # List 
for i in range(30): # 100번 반복 실험 
    fit = prediction[i].reshape(-1,1)
    fit_repeat = np.repeat(fit,7, axis=-1)
    model_fit = scaler.inverse_transform(fit_repeat)
    model_fit = np.squeeze(model_fit)[:,0]
    df = pd.DataFrame(model_fit)
    dfs.append(df)

# %%
rcParams['figure.figsize'] = 12, 4
plt.suptitle('Monte Carlo Dropout LSTM')
for i in range(0,30):
    plt.plot(pd.DataFrame(np.array(dfs)[i]))

# %%
for i in range(0,30): # 1. df 
    df = pd.DataFrame(np.array(dfs)[i])

# %%
for i in range(0,30): # 2.df[i]
    df[i] = pd.DataFrame(np.array(dfs)[i])

# %%
#df.to_csv('몬테카를로LSTM.csv')

# %%
df2 = pd.read_csv('실제값.csv')
plt.figure(figsize=(10,4))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('수출금액')
plt.plot(df2, label='수출금액')
plt.plot(df.transpose().mean(), label='평균 예측값')
plt.legend()

# %%
rmse = math.sqrt(mean_squared_error(df2['한국수출금액'], df.transpose().mean()))
print('RMSE:',rmse)
print('MAPE:',np.mean(np.abs((df2['한국수출금액']- df.transpose().mean())/ df2['한국수출금액'])*100) )
# Out:
# RMSE: 5242987290.664946
# MAPE: 7.803460300873355

# %%
df2 = pd.read_csv('실제값.csv')
plt.figure(figsize=(8,4))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('수출금액')
plt.plot(df2, label='수출금액')
plt.plot(df[5], label='Seq2Seq',color='violet') # 벡터오차수정 결과와 가장 비슷한 출력값 선정 
#plt.plot(df.transpose().min(), label='최소값')
#plt.plot(df.transpose().max(), label='최대값')
plt.legend()

# %%
rmse = math.sqrt(mean_squared_error(df2['한국수출금액'], df[5]))
print('RMSE:',rmse)
print('MAPE:',np.mean(np.abs((df2['한국수출금액']- df[5])/ df2['한국수출금액'])*100) )
# Out:
# RMSE: 2598603277.4798512
# MAPE: 3.8898827945354566

# %%
df[5]
# Out:
# 0    6.010456e+10
# 1    5.648200e+10
# 2    6.105212e+10
# 3    5.903056e+10
# 4    6.117629e+10
# 5    5.980088e+10
# Name: 5, dtype: float32

# %%
df.transpose().max()
# Out:
# 0    7.101244e+10
# 1    6.638280e+10
# 2    6.568244e+10
# 3    6.745806e+10
# 4    6.747057e+10
# 5    6.663726e+10
# dtype: float32

# %%
df.transpose().min()
# Out:
# 0    5.781152e+10
# 1    5.625789e+10
# 2    5.615657e+10
# 3    5.421656e+10
# 4    5.688882e+10
# 5    5.619768e+10
# dtype: float32

# %%
df2
# Out:
#         한국수출금액
# 0  55458996904
# 1  54154107050
# 2  63790090674
# 3  57851065625
# 4  61591387001
# 5  57689933975

# %%
df2 = pd.read_csv('실제값.csv')
plt.figure(figsize=(8,4))
plt.grid(True)
plt.xlabel('Date')
plt.ylabel('수출금액')
plt.plot(df2, label='2022.01~2022.06 한국수출금액')
plt.plot(df[5], label='Encoder-Decoder 점추정',color='red') 
plt.plot(df.transpose().min(), color='blue',alpha=0.5,label='Encoder-Decoder 최대&최소')
plt.plot(df.transpose().max(), color='blue',alpha=0.5)
plt.fill_between(df.transpose().min().index, df.transpose().min(), df.transpose().max(), alpha=0.2,color='blue')
plt.legend(loc=1)

# %% [markdown]
# ### 미분계수 ( 접선의 기울기) 기반 변수 중요도

# %%
def gradient_importance(seq, model):

    seq = tf.Variable(seq[np.newaxis,:,:], dtype=tf.float32) # TensorShape([1, 5, 7]) 3차원 텐서 변환. / 입력값 X 정의

    with tf.GradientTape() as tape: # Y = aX 식 정의 
        predictions = model(seq) # predictions -> Y / seq --> X 

    grad = tape.gradient(predictions, seq) # dy/dx 정의. X에 대한 Y의 변화. 입력값에 대한 출력값의 변화. Time Step별 기울기
    grad = tf.reduce_mean(grad, axis=1).numpy()[0] # Time Step별 미분계수 평균
    
    return grad # 결과 출력

# %%
plt.figure(figsize=(9,5))
plt.plot(X_test[0]) # 마지막 입력 시퀀스 ( 2021.08 ~ 2021.12)
plt.ylabel('시계열 정규화값'); plt.xlabel('시차(입력 길이)')
plt.legend(train.columns)
plt.show()

# %%
grad_imp = gradient_importance(X_test[0],model) # 편미분계수 크기 (기울기 크기 )

# %%
plt.figure(figsize=(7,5))
plt.bar(range(len(grad_imp)), grad_imp,color='blue')
plt.xticks(range(len(train.columns)), train.columns, rotation=45)
plt.ylabel('gradients')
plt.title('출력값(2022.01 ~ 2022.06) 예측에 대한 변수 중요도')
plt.suptitle('입력변수 ( 2021.08 ~ 2021.12)')
plt.show()

# %%
grad_imp
# Out:
# array([ 0.31221452,  0.4678561 ,  0.10306738,  0.16123398,  0.21199706,
#         0.04975183, -0.18793163], dtype=float32)

# %% [markdown]
# #### ** 미분계수 절대값이 클수록 기울기가 큼 --> 출력변수에 대한 해당 입력변수의 변화가 그만큼 중요하게 작용
